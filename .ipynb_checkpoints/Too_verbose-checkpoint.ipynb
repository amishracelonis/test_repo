# %%
import numpy as np

# %%
for i in range(0,100):
    print(f"printing count {i}\n")
    print("Test message\n")
# Out:
# printing count 0
#
# Test message
#
# printing count 1
#
# Test message
#
# printing count 2
#
# Test message
#
# printing count 3
#
# Test message
#
# printing count 4
#
# Test message
#
# printing count 5
#
# Test message
#
# printing count 6
#
# Test message
#
# printing count 7
#
# Test message
#
# printing count 8
#
# Test message
#
# printing count 9
#
# Test message
#
# printing count 10
#
# Test message
#
# printing count 11
#
# Test message
#
# printing count 12
#
# Test message
#
# printing count 13
#
# Test message
#
# printing count 14
#
# Test message
#
# printing count 15
#
# Test message
#
# printing count 16
#
# Test message
#
# printing count 17
#
# Test message
#
# printing count 18
#
# Test message
#
# printing count 19
#
# Test message
#
# printing count 20
#
# Test message
#
# printing count 21
#
# Test message
#
# printing count 22
#
# Test message
#
# printing count 23
#
# Test message
#
# printing count 24
#
# Test message
#
# printing count 25
#
# ...
